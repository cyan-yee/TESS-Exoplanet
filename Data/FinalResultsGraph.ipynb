# %%
import numpy as np
import pandas as pd
import batman
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 12})

def batman_curve(time, rp, a, inc, t0, per, ecc, w, u=[0.3,0.2], limb_dark="quadratic"):
    params = batman.TransitParams()
    params.t0 = t0
    params.per = per
    params.rp = rp
    params.a = a
    params.inc = inc
    params.ecc = ecc
    params.w = w
    params.u = u
    params.limb_dark = limb_dark
    m = batman.TransitModel(params, time)
    return m.light_curve(params)

fig, axes = plt.subplots(2, 2, figsize=(15,10))

data = pd.read_csv('1009_01_TIC107782586_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 2231.5
cond2 = t < 2232.8
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.036, 4.55, 87.94, 2232.14, 2.43, 0.81, 268.91)
axes[0,0].scatter(t, flux, s=2, color="black")
axes[0,0].plot(t, model_best, color="C1", lw=2)
axes[0,0].set_xlabel("Time [BTJD]")
axes[0,0].set_ylabel("Relative flux")
axes[0,0].set_title("TIC 107782586")

data = pd.read_csv('1039_01_TIC461867584_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 2285
cond2 = t < 2288
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.033, 2.89, 87.93, 2285.8, 1.26, 0.84, 268)
axes[0, 1].scatter(t, flux, s=2, color="black")
axes[0, 1].plot(t, model_best, color="C1", lw=1)
axes[0, 1].set_xlabel("Time [BTJD]")
axes[0, 1].set_ylabel("Relative flux")
axes[0, 1].set_title("TIC 461867584")

data = pd.read_csv('1114_01_TIC409934330_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 2046.25
cond2 = t < 2047.05
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux=flux/np.mean(flux)
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.08, 5.67, 88.89, 2046.7, 2.01, 0.61, 248.31)
axes[1, 0].scatter(t, flux, s=2, color="black")
axes[1, 0].plot(t, model_best, color="C1", lw=1)
axes[1, 0].set_xlabel("Time [BTJD]")
axes[1, 0].set_ylabel("Relative flux")
axes[1, 0].set_title("TIC 409934330")

data = pd.read_csv('1149_01_TIC117789567_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 2801
cond2 = t < 2802.4
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.07, 5.07, 87.72, 2801.41, 2.21, 0.63, 260.9)
axes[1, 1].scatter(t, flux, s=2, color="black")
axes[1, 1].plot(t, model_best, color="C1", lw=1)
axes[1, 1].set_xlabel("Time [BTJD]")
axes[1, 1].set_ylabel("Relative flux")
axes[1, 1].set_title("TIC 117789567")

plt.suptitle("Final Transit Fits with Batman Light Curve (a)")
plt.tight_layout()
plt.show()
#plt.savefig("results.pdf")
#plt.close()

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,10))

data = pd.read_csv('1356_01_TIC277566483_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 3362.8
cond2 = t < 3363.125
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux=flux/np.median(flux)
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.04, 5.96, 87.7, 3362.96, 2.17, 0.39, 223.9)
axes[0,0].scatter(t, flux, s=2, color="black")
axes[0,0].plot(t, model_best, color="C1", lw=2)
axes[0,0].set_xlabel("Time [BTJD]")
axes[0,0].set_ylabel("Relative flux")
axes[0, 0].set_title("TIC 277566483")

data = pd.read_csv('1457_01_TIC176860064_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 3605
cond2 = t < 3607.5
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.02, 4.44, 89.44, 3606.18, 2.92, 0.9, 269.53)
axes[0,1].scatter(t, flux, s=2, color="black")
axes[0,1].plot(t, model_best, color="C1", lw=2)
axes[0,1].set_xlabel("Time [BTJD]")
axes[0,1].set_ylabel("Relative flux")
axes[0, 1].set_title("TIC 176860064")

data = pd.read_csv('1531_01_TIC312678993_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 2900.4
cond2 = t < 2900.8
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.03, 10.68, 87.71, 2900.6, 1.91, 0.43, 189.9)
axes[1,0].scatter(t, flux, s=2, color="black")
axes[1,0].plot(t, model_best, color="C1", lw=2)
axes[1,0].set_xlabel("Time [BTJD]")
axes[1,0].set_ylabel("Relative flux")
axes[1, 0].set_title("TIC 312678993")

data = pd.read_csv('1976_01_TIC329888006_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 2349
cond2 = t < 2350
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux = flux/np.median(flux)
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.04, 4.7, 87.93, 2349.49, 2.3, 0.54, 269.21)
axes[1,1].scatter(t, flux, s=2, color="black")
axes[1,1].plot(t, model_best, color="C1", lw=2)
axes[1,1].set_xlabel("Time [BTJD]")
axes[1,1].set_ylabel("Relative flux")
axes[1, 1].set_title("TIC 329888006")
plt.savefig("results3.pdf")
plt.close

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,10))

data = pd.read_csv('1986_01_TIC468997317_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 2291.4
cond2 = t < 2292.1
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.06, 4.69, 87.71, 2291.75, 2.35, 0.62, 267.32)
axes[0,0].scatter(t, flux, s=2, color="black")
axes[0,0].plot(t, model_best, color="C1", lw=2)
axes[0,0].set_xlabel("Time [BTJD]")
axes[0,0].set_ylabel("Relative flux")
axes[0, 0].set_title("TIC 468997317")

data = pd.read_csv('2183_01_TIC1715469662_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 3500.85
cond2 = t < 3501.18
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.045, 1.28, 88.18, 3500.99, 0.41, 0.67, 272.8)
axes[0,1].scatter(t, flux, s=2, color="black")
axes[0,1].plot(t, model_best, color="C1", lw=2)
axes[0,1].set_xlabel("Time [BTJD]")
axes[0,1].set_ylabel("Relative flux")
axes[0, 1].set_title("TIC 1715469662")

data = pd.read_csv('2232_01_TIC439444938_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 2054.15
cond2 = t < 2054.6
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux = flux/np.median(flux)
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.03, 4.82, 87.81, 2054.43, 2.18, 0.41, 257.64)
axes[1,0].scatter(t, flux, s=2, color="black")
axes[1,0].plot(t, model_best, color="C1", lw=2)
axes[1,0].set_xlabel("Time [BTJD]")
axes[1,0].set_ylabel("Relative flux")
axes[1,0].set_title("TIC 439444938")

data = pd.read_csv('2388_01_TIC382625239_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 3063
cond2 = t < 3064
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.01, 6.27, 87.74, 3063.5, 2.23, 0.48, 247.28)
axes[1,1].scatter(t, flux, s=2, color="black")
axes[1,1].plot(t, model_best, color="C1", lw=2)
axes[1,1].set_xlabel("Time [BTJD]")
axes[1,1].set_ylabel("Relative flux")
axes[1,1].set_title("TIC 439444938")
plt.tight_layout()
plt.savefig("results3.pdf")
plt.close

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,10))

data = pd.read_csv('4175_01_TIC952046774_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 2300
cond2 = t < 2320
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.06, 3.47, 89.31, 2311.34, 2.03, 0.9, 271.8)
axes[0,0].scatter(t, flux, s=2, color="black")
axes[0,0].plot(t, model_best, color="C1", lw=2)
axes[0,0].set_xlabel("Time [BTJD]")
axes[0,0].set_ylabel("Relative flux")
axes[0, 0].set_title("TIC 439444938")

data = pd.read_csv('4391_01_TIC66620917_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 3072.34
cond2 = t < 3072.425
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.03, 11.73, 88.21, 3072.38, 1.99, 0.45, 197.23)
axes[0,1].scatter(t, flux, s=2, color="black")
axes[0,1].plot(t, model_best, color="C1", lw=2)
axes[0,1].set_xlabel("Time [BTJD]")
axes[0,1].set_ylabel("Relative flux")
axes[0, 1].set_title("TIC 439444938")

data = pd.read_csv('4494_01_TIC40466976_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 2426.75
cond2 = t < 2427.9
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.02, 4.8, 87.91, 2427.4, 2.32, 0.59, 268.93)
axes[1,0].scatter(t, flux, s=2, color="black")
axes[1,0].plot(t, model_best, color="C1", lw=2)
axes[1,0].set_xlabel("Time [BTJD]")
axes[1,0].set_ylabel("Relative flux")
axes[1,0].set_title("TIC 40466976")

data = pd.read_csv('568_01_TIC37575651_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 2259
cond2 = t < 2261.5
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.02, 2.04, 88.25, 2259.37, 0.56, 0.56, 261.68)
axes[1,1].scatter(t, flux, s=2, color="black")
axes[1,1].plot(t, model_best, color="C1", lw=2)
axes[1,1].set_xlabel("Time [BTJD]")
axes[1,1].set_ylabel("Relative flux")
axes[1,1].set_title("TIC 439444938")
plt.tight_layout()
plt.savefig("results4.pdf")
plt.close()

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,10))

data = pd.read_csv('637_01_TIC133334108_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 2276
cond2 = t < 2280
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.02, 3.64, 88.93, 2276.97, 1.67, 0.76, 261.68)
axes[0,0].scatter(t, flux, s=2, color="black")
axes[0,0].plot(t, model_best, color="C1", lw=2)
axes[0,0].set_xlabel("Time [BTJD]")
axes[0,0].set_ylabel("Relative flux")
axes[0,0].set_title("TIC 439444938")

data = pd.read_csv('651_01_TIC72090501_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 2207.956
cond2 = t < 2208.5
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.04, 4.79, 87.64, 2208.26, 2.33, 0.53, 265.3)
axes[0,1].scatter(t, flux, s=2, color="black")
axes[0,1].plot(t, model_best, color="C1", lw=2)
axes[0,1].set_xlabel("Time [BTJD]")
axes[0,1].set_ylabel("Relative flux")
axes[0,1].set_title("TIC 439444938")

data = pd.read_csv('779_01_TIC374095457_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 3017.5
cond2 = t < 3019.3
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.06, 3.67, 87.78, 3018.39, 2.1, 0.89, 284.83)
axes[1,0].scatter(t, flux, s=2, color="black")
axes[1,0].plot(t, model_best, color="C1", lw=2)
axes[1,0].set_xlabel("Time [BTJD]")
axes[1,0].set_ylabel("Relative flux")
axes[1,0].set_title("TIC 439444938")

data = pd.read_csv('862_01_TIC309254930_cleaned_lc.csv')
flux= data['flux_normalized'].values
t = data['time_btjd'].values
flux_err = data['flux_err'].values
cond1 = t > 3064
cond2 = t < 3065.1
t = t[cond1 & cond2] 
flux = flux[cond1 & cond2]
flux_err = flux_err[cond1 & cond2]

model_best = batman_curve(t, 0.05, 5.16, 85.17, 3064.54, 2.9, 0.89, 269.89)
axes[1,1].scatter(t, flux, s=2, color="black")
axes[1,1].plot(t, model_best, color="C1", lw=2)
axes[1,1].set_xlabel("Time [BTJD]")
axes[1,1].set_ylabel("Relative flux")
axes[1,1].set_title("TIC 439444938")
plt.tight_layout()
plt.savefig("results5.pdf")
plt.close
